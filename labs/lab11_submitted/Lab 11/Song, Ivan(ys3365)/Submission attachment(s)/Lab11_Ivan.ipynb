# %% [markdown]
# # Lab 11 (due Dec. 12)

# %% [markdown]
# **Song, Ivan**
#
# **ys3365**
#
# Double click this text cell to edit it. Replace the lines above with your own name and netID.
#
# Press `Shift` + `Enter` to exit editing mode.

# %% [markdown]
# ## Problem 1: Leatherback Sea Turtles Population (30 points)
#
#
# Leatherback Sea Turtle population is declining due to many reasons. The paper published in 2013 [Long‐term decline of the western Pacific leatherback, Dermochelys coriacea: a globally important sea turtle population](https://esajournals.onlinelibrary.wiley.com/doi/full/10.1890/ES12-00348.1#i2150-8925-4-2-art25-Hitipeuw1) contains information about the estimated counts of nests and female leatherbacks in Jamursba Medi.
# Your job for this problem is to use this data to calculate a few things:
# - The female turtles lay eggs in multiple nests. What is the approximate number of nests in which a single female lays eggs? How did you estimate this?
# - What is the percentage by which the number of nests differs in each year from the previous year (assume that the previous year is 100%, calculate the percentage increase/decrease for the next year)? Write a program that shows the table.
# What is the average percentage change? Is it a decrease or increase on average? Explain how you calculated it.
# - Plot the number of nests and number of females as a function of years (years on the horizontal axis). Both should be included in a single plot.
#
#
# For each of the questions, provide the program that answers it, but also use a text cell (or comments in the program) to actually answer the question.
#
#
#
# Use the CODE cell below to continue with your program.

# %%
number_of_nests = [14522, 3261, 4448, 4517, 4633, 6929, 4879, 3429,2383,3321,\
                   2143,3790,3597,2626,2674,2107,2077,2055,1720,1596]
number_of_females = [2640,593,809,821,842,1260,887,623,433,604,390,689,654,477,\
                     486,383,378,374,313,290]
years = list(range(1984,2004))

# Question 1: Calculate What is the approximate number of nests in which a single female lays eggs.
print('Question 1 \n')
nest_of_one_female = [0] * len(number_of_females)
print("Approximate number of nests in which a single female lays eggs")
for index in range (len(nest_of_one_female)):
  nest_of_one_female[index] = number_of_nests[index] / number_of_females[index]
  print(years[index],format(nest_of_one_female[index], '.6f'), sep = ": ")
  
# Question 2: What is the percentage by which the number of nests differs in each year from the previous year?
print('\nQuestion 2 \n')
ratio = [0] * len(number_of_nests)
print("The percentage by which the number of nests differs in each year from the previous year")
for index in range (len(number_of_nests)):
  if index > 0:
    ratio[index] = number_of_nests[index] / number_of_nests[index - 1] * 100 - 100
  print(years[index], format(ratio[index], '.2f'), sep = ": ", end = "%\n")
average = sum(ratio) / len(ratio) - 1
print("Average: ", average)

# Question 3: Plot the number of nests and number of females as a function of years.
print('\nQuestion 3 \n')
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4), dpi=100, facecolor='gray')
plt.plot(years, number_of_nests, 'b')
plt.plot(years, number_of_females, 'r')
plt.plot(years, number_of_nests, 'g.')
plt.plot(years, number_of_females, 'g.')
plt.xlabel("years")
plt.ylabel("number of nests (blue) and females (red)")
plt.show()
# Out:
# Question 1
#
# Approximate number of nests in which a single female lays eggs
# 1984: 5.500758
# 1985: 5.499157
# 1986: 5.498146
# 1987: 5.501827
# 1988: 5.502375
# 1989: 5.499206
# 1990: 5.500564
# 1991: 5.504013
# 1992: 5.503464
# 1993: 5.498344
# 1994: 5.494872
# 1995: 5.500726
# 1996: 5.500000
# 1997: 5.505241
# 1998: 5.502058
# 1999: 5.501305
# 2000: 5.494709
# 2001: 5.494652
# 2002: 5.495208
# 2003: 5.503448
#
# Question 2
#
# The percentage by which the number of nests differs in each year from the previous year
# 1984: 0.00%
# 1985: -77.54%
# 1986: 36.40%
# 1987: 1.55%
# 1988: 2.57%
# 1989: 49.56%
# 1990: -29.59%
# 1991: -29.72%
# 1992: -30.50%
# 1993: 39.36%
# 1994: -35.47%
# 1995: 76.85%
# 1996: -5.09%
# 1997: -26.99%
# 1998: 1.83%
# 1999: -21.20%
# 2000: -1.42%
# 2001: -1.06%
# 2002: -16.30%
# 2003: -7.21%
# Average:  -4.699442682948183
#
# Question 3

# %% [markdown]
# 1.ANSWER of Q1:
# The number of nests divided by number of females will get the number of nests that belong to each female. From this formula we can calculate approximate number of nests in which a single female lays eggs. I first set a list for the answers in each year that has the same length as years, number of females, and number of nests. Then, I used a for loop, looping the index of the list, and import calculated result for each index into the lists corresponding items. Then I print years[index] and nest_of_one_female[index] for every loop to show the results vertically in a table form.
#
# 2.ANSWER of Q2:
# For question 2, I first created a list of "0"s to be used to store all the ratios. Then, I iterated the index numbers of len(ratio), and replaced every item (originally "0"s) with the new ratio calculated using the formula below:
#
# ratio[index] = number_of_nests[index] / number_of_nests[index - 1] * 100 - 100
#
# Then, I used the sum(ratio) and len(ratio) function to calculate the average. Since I set the first item in the ratio list as "0" because the number of ratio values should be one less than the length of the data lists, I used sum(ratio) / len(ratio) - 1 to calculate the actual average.
#
# The average of the percentage of change between 1984 and 2004 is negative, meaning that in general, the number of nests is in a generally decreasing trend.
#
# 3.ANSWER of Q3: The "years" list is on the x axis, and both the "number_of_nests" and "number_of_females" lists are on the y axis. So I used plt.plot (x, y) to make the plot, and differentiated the two lines using different colors. I also labeled the x and y axis to make the graph clear.

# %% [markdown]
# ## Problem 2: Fobonacci Numbers and the Golden Ratio (35 points)
#
#
# You just heard two different talks on the topic of Fibonacci numbers and the golden ratio.
#
# Write a program that creates a list of the first 50 Fibonacci numbers.
#
# Once the numbers are calculated the program should calculate the ratio of the two consecutive numbers for each pair of Fibonacci numbers:
#
# $$\dfrac{\text{Fibonacci number at position i}}{\text{Fibonacci number at position i-1}}$$
#
# --
#
# The __golden ratio__ can be calculated using the following formula:
#
# $$\dfrac{1 + \sqrt{5}}{2} $$
#
# Compare the value of the golden ratio to the values obtained by calculating the ratios of consecutive Fibonacci numbers.
#
#
#
# Create a CODE cell below to write your program. Your answers should be in a TEXT cell or in the comments in the program.

# %%
fib = [1] * 50
ratio = [0] * 50
golden_ratio = (1 + 5 ** (1/2))/2

print("FiboNacci Number", "Fibbonaci number ratio", "Golden Ratio", sep = "\t"*2)
print('-' * 100)

for index in range (len(fib)):
  if index > 1:
    fib[index] = fib[index - 1] + fib[index - 2]
  if index > 0:
    ratio[index] = format(fib[index] / fib[index - 1], '.6f')
  print(fib[index], ratio [index], golden_ratio, sep = "\t" * 4)
# Out:
# FiboNacci Number		Fibbonaci number ratio		Golden Ratio
# ----------------------------------------------------------------------------------------------------
# 1				0				1.618033988749895
# 1				1.000000				1.618033988749895
# 2				2.000000				1.618033988749895
# 3				1.500000				1.618033988749895
# 5				1.666667				1.618033988749895
# 8				1.600000				1.618033988749895
# 13				1.625000				1.618033988749895
# 21				1.615385				1.618033988749895
# 34				1.619048				1.618033988749895
# 55				1.617647				1.618033988749895
# 89				1.618182				1.618033988749895
# 144				1.617978				1.618033988749895
# 233				1.618056				1.618033988749895
# 377				1.618026				1.618033988749895
# 610				1.618037				1.618033988749895
# 987				1.618033				1.618033988749895
# 1597				1.618034				1.618033988749895
# 2584				1.618034				1.618033988749895
# 4181				1.618034				1.618033988749895
# 6765				1.618034				1.618033988749895
# 10946				1.618034				1.618033988749895
# ...

# %% [markdown]
# ANSWER: I first created a list for fibonacci numbers containing 50 "1"s, and a list for the list of values of ratio of the adjacent numbers containing 50 "0"s (Since first two numbers in fibonacci sequence are 1, and the first ratio should no exist, and shouldn't be represented by 1). Then, I decided to calculate the fibonacci numbers and ratios using a for loop: "for index in range (len(fib))" (which is basically in range (50)), and left the first two items in the fibonacci lists remain as "1" and the first item in the ratio list remain as "0" using two if statements; for all later items I used functions below:
#
# fib[index] = fib[index - 1] + fib[index - 2]
#
# ratio[index] = fib[index] / fib[index - 1]
#
# Then I set a variable for golden ratio, and compared the list of ratios and the golden ratio in a table.
#
# The result is that the bigger the fibonacci numbers get, the ratio of those adjacent numbers becomes closer to the golden ratio of 1.618.
#
# There's also another trend. all the odd ratios (ratios in odd position of the list) are smaller than the actual golden ratio, and all even ratios are bigger than the golden ratio. The difference of both odd and even ratios to the golden ratio is decreasing when the fibonacci numbers get bigger.

# %% [markdown]
# ## Problem 3: Subway Fares in NYC (35 points)
#
#
# The Wikipedia has an article that shows the history of the transit fares in NYC. The part of the article that talks about subway fares is titled [Subway and local buses](https://en.wikipedia.org/wiki/New_York_City_transit_fares#Subway_and_local_buses). You will need the data provided in that section to complete this problem.
#
# You will also need the [Inflation Calculator](https://www.bls.gov/data/inflation_calculator.htm) that we used at the beginning of the semester.
#
# Complete the following tasks in the CODE cells and TEXT cells below this problem description.
#
# - Plot the history of subway fares from 1905 to 2018. Make sure that your plot includes ALL the years, not just the years of the fare increase. For example, the fare was 5 cents from 1905 to 1948, this means that your plot should have a flat line for these years and then the increase in 1948 to 10 cents.
#
# - Use the inflation calculator to figure out what the price of a subway fare should be, if the only increases followed the inflation rate. (The calculator starts at 1913, not 1905, so use that year as a starting point.)
#
# - For each of the fare increases, calculate the percentage increase over the previous fare. Show a table containing the year of the increase and the percentage increase that was applied. (Read through your results to verify that they do make sense.)
#
# Note: for all the fares use the _base fare_.

# %%
# Question 1: Plot the history of subway fares from 1905 to 2018.
year = list(range(1905,2019))
fare = [0.05]*43 + [0.1]*5 + [0.15]*13 + [0.2]*4 + [0.3]*2 + [0.35]*3 + [0.5]*5 + [0.6] + [0.75]*3 + [0.9]*2 + [1]*4 + [1.15]*2 + [1.25]*3 + [1.5]*8 + [2]*6 + [2.25]*4 + [2.5]*2 + [2.75]*4
print('Question 1 \n')
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4), dpi=100, facecolor='gray')
plt.plot(year, fare, 'r.')
plt.plot(year, fare, 'y')
plt.xlabel("Year (1905 to 2018)")
plt.ylabel("Subway fares ($)")
plt.show()

# Question 2: Use the inflation calculator to figure out what the price of a subway fare should be, if the only increases followed the inflation rate.
print('\nQuestion 2 \n')
print("See TEXT Cell")

# Question 3: Calculate the percentage increase over the previous fare.
print('\nQuestion 3 \n')
print("Year of Increase", "Percentage of Increase", sep = "\t"*2)
print("-" * 60)
ratio_list = [0] * len(fare)
for index in range (len(fare)):
  if fare[index] > fare[index - 1]:
    ratio_list[index] = (fare[index] / fare[index-1] - 1) * 100
    print(year[index], "\t"*4, format(ratio_list[index], '.2f'), "%", sep = "")
# Out:
# Question 1
# Question 2
#
# See TEXT Cell
#
# Question 3
#
# Year of Increase		Percentage of Increase
# ------------------------------------------------------------
# 1948				100.00%
# 1953				50.00%
# 1966				33.33%
# 1970				50.00%
# 1972				16.67%
# 1975				42.86%
# 1980				20.00%
# 1981				25.00%
# 1984				20.00%
# 1986				11.11%
# 1990				15.00%
# 1992				8.70%
# 1995				20.00%
# 2003				33.33%
# 2009				12.50%
# 2013				11.11%
# 2015				10.00%

# %% [markdown]
# Question 1:
#
# See CODE Cell
#
# Question 2:
#
# I used the inflation calculator to solve this problem.
#
# I first calculated the difference between 2.75 and 0.05, which is the total amount of fare added from 1905 (or1913) to 2018. Then, I used the inflation calculator, and entered 0.05 on January 1913, and set the new date to October 2018, which is the latest year available for calculation. The calculator shows that \$0.05 in 1913 has the same buying power as \$1.29 in the present. This means that is will be reasonable for the fare nowadays to be \$1.29. However, it is \$2.75, which is \$1.46 more than it should be if only following the inflation rate.
#
# Question 3:
#
# See CODE Cell
