# %% [markdown]
# # Lab 11 (due Dec. 12)

# %% [markdown]
# **Bates, Sofia**
#
# **sib279**
#
# Double click this text cell to edit it. Replace the lines above with your own name and netID.
#
# Press `Shift` + `Enter` to exit editing mode.

# %% [markdown]
# ## Problem 1: Leatherback Sea Turtles Population (30 points)
#
#
# Leatherback Sea Turtle population is declining due to many reasons. The paper published in 2013 [Long‐term decline of the western Pacific leatherback, Dermochelys coriacea: a globally important sea turtle population](https://esajournals.onlinelibrary.wiley.com/doi/full/10.1890/ES12-00348.1#i2150-8925-4-2-art25-Hitipeuw1) contains information about the estimated counts of nests and female leatherbacks in Jamursba Medi.
# Your job for this problem is to use this data to calculate a few things:
# - The female turtles lay eggs in multiple nests. What is the approximate number of nests in which a single female lays eggs? How did you estimate this?
# - What is the percentage by which the number of nests differs in each year from the previous year (assume that the previous year is 100%, calculate the percentage increase/decrease for the next year)? Write a program that shows the table.
# What is the average percentage change? Is it a decrease or increase on average? Explain how you calculated it.
# - Plot the number of nests and number of females as a function of years (years on the horizontal axis). Both should be included in a single plot.
#
#
# For each of the questions, provide the program that answers it, but also use a text cell (or comments in the program) to actually answer the question.
#
#
#
# Use the CODE cell below to continue with your program.

# %% [markdown]
# The approximate number of nests where a female lays eggs is about 5.5, which was found by dividing the number nests by the number of females, adding those quotients together and finding the average.
#
# The average percentage change is a 24.51% decrease, which was calculated by subtracting the current year by the year before, dividing by the current year, and multiplying by 100. All of the percentages were then added together and divided by the total.

# %%
number_of_nests = [14522, 3261, 4448, 4517, 4633, 6929, 4879, 3429,2383,3321,\
                   2143,3790,3597,2626,2674,2107,2077,2055,1720,1596]
number_of_females = [2640,593,809,821,842,1260,887,623,433,604,390,689,654,477,\
                     486,383,378,374,313,290]
years = list(range(1984,2004))

sumofnests = 0
counter = 0
year = 1
sumofpercentages = 0
upordown = ""

for i in range (len(number_of_nests)):
  num = number_of_nests[i]/number_of_females[i]
  sumofnests += num
averagenests = sumofnests/(len(number_of_nests))

print("The approximate number of nests in which a single female lays eggs is", averagenests)

while year < len(number_of_nests):
  first = number_of_nests[year] - number_of_nests[year-1]
  second = first/number_of_nests[year]
  percentage = second*100
  sumofpercentages += percentage
  print("Year ", year, "   ||   ", format(percentage, '.2f'),"%", sep='')
  year += 1
averagepercentage = sumofpercentages/year
print("The average percentage is ", format(averagepercentage,".2f"), "%", sep='')

import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(15,10), dpi=100, facecolor='gray')
plt.plot(years, number_of_nests, 'r', label="Number of Nests")
plt.plot(years, number_of_females, 'b', label= "Number of Females")
plt.xlabel('Years') 
plt.legend(loc='upper right')
plt.show()
# Out:
# The approximate number of nests in which a single female lays eggs is 5.500003653961009
# Year 1   ||   -345.32%
# Year 2   ||   26.69%
# Year 3   ||   1.53%
# Year 4   ||   2.50%
# Year 5   ||   33.14%
# Year 6   ||   -42.02%
# Year 7   ||   -42.29%
# Year 8   ||   -43.89%
# Year 9   ||   28.24%
# Year 10   ||   -54.97%
# Year 11   ||   43.46%
# Year 12   ||   -5.37%
# Year 13   ||   -36.98%
# Year 14   ||   1.80%
# Year 15   ||   -26.91%
# Year 16   ||   -1.44%
# Year 17   ||   -1.07%
# Year 18   ||   -19.48%
# Year 19   ||   -7.77%
# The average percentage is -24.51%

# %% [markdown]
# ## Problem 2: Fobonacci Numbers and the Golden Ratio (35 points)
#
#
# You just heard two different talks on the topic of Fibonacci numbers and the golden ratio.
#
# Write a program that creates a list of the first 50 Fibonacci numbers.
#
# Once the numbers are calculated the program should calculate the ratio of the two consecutive numbers for each pair of Fibonacci numbers:
#
# $$\dfrac{\text{Fibonacci number at position i}}{\text{Fibonacci number at position i-1}}$$
#
# --
#
# The __golden ratio__ can be calculated using the following formula:
#
# $$\dfrac{1 + \sqrt{5}}{2} $$
#
# Compare the value of the golden ratio to the values obtained by calculating the ratios of consecutive Fibonacci numbers.
#
#
#
# Create a CODE cell below to write your program. Your answers should be in a TEXT cell or in the comments in the program.

# %% [markdown]
# After the 8th Fibonacci number, the two ratios become very close, but they don't become exactly the same until the 41st number.

# %%
import math
fibonaccinumbers = [0,1]
ratios = [0, 0]
goldenratio = (1 + math.sqrt(5))/2
for i in range (2, 51):
  nextnum = fibonaccinumbers[i-1] + fibonaccinumbers[i-2]
  fibonaccinumbers.append(nextnum)
for r in range (len(fibonaccinumbers)-2):
  nextratio = fibonaccinumbers[r+2]/fibonaccinumbers[r+1]
  ratios.append(nextratio)
print("  || Fibonacci Number || Golden Ratio \t\t|| Fibonacci Ratio")
for x in range (len(fibonaccinumbers)):
  print(x, "||\t", fibonaccinumbers[x], "\t\t||", goldenratio, "\t||", ratios[x])
# Out:
#   || Fibonacci Number || Golden Ratio 		|| Fibonacci Ratio
# 0 ||	 0 		|| 1.618033988749895 	|| 0
# 1 ||	 1 		|| 1.618033988749895 	|| 0
# 2 ||	 1 		|| 1.618033988749895 	|| 1.0
# 3 ||	 2 		|| 1.618033988749895 	|| 2.0
# 4 ||	 3 		|| 1.618033988749895 	|| 1.5
# 5 ||	 5 		|| 1.618033988749895 	|| 1.6666666666666667
# 6 ||	 8 		|| 1.618033988749895 	|| 1.6
# 7 ||	 13 		|| 1.618033988749895 	|| 1.625
# 8 ||	 21 		|| 1.618033988749895 	|| 1.6153846153846154
# 9 ||	 34 		|| 1.618033988749895 	|| 1.619047619047619
# 10 ||	 55 		|| 1.618033988749895 	|| 1.6176470588235294
# 11 ||	 89 		|| 1.618033988749895 	|| 1.6181818181818182
# 12 ||	 144 		|| 1.618033988749895 	|| 1.6179775280898876
# 13 ||	 233 		|| 1.618033988749895 	|| 1.6180555555555556
# 14 ||	 377 		|| 1.618033988749895 	|| 1.6180257510729614
# 15 ||	 610 		|| 1.618033988749895 	|| 1.6180371352785146
# 16 ||	 987 		|| 1.618033988749895 	|| 1.618032786885246
# 17 ||	 1597 		|| 1.618033988749895 	|| 1.618034447821682
# 18 ||	 2584 		|| 1.618033988749895 	|| 1.6180338134001253
# 19 ||	 4181 		|| 1.618033988749895 	|| 1.618034055727554
# 20 ||	 6765 		|| 1.618033988749895 	|| 1.6180339631667064
# 21 ||	 10946 		|| 1.618033988749895 	|| 1.6180339985218033
# 22 ||	 17711 		|| 1.618033988749895 	|| 1.618033985017358
# 23 ||	 28657 		|| 1.618033988749895 	|| 1.6180339901755971
# 24 ||	 46368 		|| 1.618033988749895 	|| 1.618033988205325
# 25 ||	 75025 		|| 1.618033988749895 	|| 1.618033988957902
# 26 ||	 121393 		|| 1.618033988749895 	|| 1.6180339886704431
# 27 ||	 196418 		|| 1.618033988749895 	|| 1.6180339887802426
# 28 ||	 317811 		|| 1.618033988749895 	|| 1.618033988738303
# 29 ||	 514229 		|| 1.618033988749895 	|| 1.6180339887543225
# 30 ||	 832040 		|| 1.618033988749895 	|| 1.6180339887482036
# 31 ||	 1346269 		|| 1.618033988749895 	|| 1.6180339887505408
# 32 ||	 2178309 		|| 1.618033988749895 	|| 1.6180339887496482
# 33 ||	 3524578 		|| 1.618033988749895 	|| 1.618033988749989
# 34 ||	 5702887 		|| 1.618033988749895 	|| 1.618033988749859
# 35 ||	 9227465 		|| 1.618033988749895 	|| 1.6180339887499087
# 36 ||	 14930352 		|| 1.618033988749895 	|| 1.6180339887498896
# 37 ||	 24157817 		|| 1.618033988749895 	|| 1.618033988749897
# 38 ||	 39088169 		|| 1.618033988749895 	|| 1.618033988749894
# 39 ||	 63245986 		|| 1.618033988749895 	|| 1.6180339887498951
# 40 ||	 102334155 		|| 1.618033988749895 	|| 1.6180339887498947
# 41 ||	 165580141 		|| 1.618033988749895 	|| 1.618033988749895
# 42 ||	 267914296 		|| 1.618033988749895 	|| 1.618033988749895
# 43 ||	 433494437 		|| 1.618033988749895 	|| 1.618033988749895
# 44 ||	 701408733 		|| 1.618033988749895 	|| 1.618033988749895
# 45 ||	 1134903170 		|| 1.618033988749895 	|| 1.618033988749895
# 46 ||	 1836311903 		|| 1.618033988749895 	|| 1.618033988749895
# 47 ||	 2971215073 		|| 1.618033988749895 	|| 1.618033988749895
# 48 ||	 4807526976 		|| 1.618033988749895 	|| 1.618033988749895
# 49 ||	 7778742049 		|| 1.618033988749895 	|| 1.618033988749895
# 50 ||	 12586269025 		|| 1.618033988749895 	|| 1.618033988749895

# %% [markdown]
# ## Problem 3: Subway Fares in NYC (35 points)
#
#
# The Wikipedia has an article that shows the history of the transit fares in NYC. The part of the article that talks about subway fares is titled [Subway and local buses](https://en.wikipedia.org/wiki/New_York_City_transit_fares#Subway_and_local_buses). You will need the data provided in that section to complete this problem.
#
# You will also need the [Inflation Calculator](https://www.bls.gov/data/inflation_calculator.htm) that we used at the beginning of the semester.
#
# Complete the following tasks in the CODE cells and TEXT cells below this problem description.
#
# - Plot the history of subway fares from 1905 to 2018. Make sure that your plot includes ALL the years, not just the years of the fare increase. For example, the fare was 5 cents from 1905 to 1948, this means that your plot should have a flat line for these years and then the increase in 1948 to 10 cents.
#
# - Use the inflation calculator to figure out what the price of a subway fare should be, if the only increases followed the inflation rate. (The calculator starts at 1913, not 1905, so use that year as a starting point.)
#
# - For each of the fare increases, calculate the percentage increase over the previous fare. Show a table containing the year of the increase and the percentage increase that was applied. (Read through your results to verify that they do make sense.)
#
# Note: for all the fares use the _base fare_.

# %% [markdown]
# The price of a subway fare should be $1.29

# %%
years = list(range(1905,2019))
years2 = list(range(1913,2019))
prices = []
percentages = []
counter = 1
for i in range(1905,1949):
  prices.append(0.05)
prices = prices + [0.07]*2
prices = prices + [0.10]*4
prices = prices + [0.13]
for x in range(1956,1967):
  prices.append(0.15)
prices = prices + [0.2]*4
prices = prices + [0.3]
prices = prices + [0.35]*4
prices = prices + [0.5]*5
prices = prices + [0.6]
prices = prices + [0.75]*3
prices = prices + [0.9]
prices = prices + [1]*4
prices = prices + [1.15]*2
prices = prices + [1.25]*5
for a in range (1995, 2003):
  prices.append(1.5)
prices = prices + [2]*5
prices = prices + [2.25]*4
prices = prices + [2.5]*2
prices = prices + [2.75] *3

while counter < len(prices):
  first = prices[counter] - prices[counter-1]
  second = first/prices[counter]
  percentage = second*100
  percentages.append(percentage)
  counter += 1
  
print("Year \t Percentage Increase")
print("----------------------------------")
for l in range (len(years2)):
  print(years2[l], "\t", format(percentages[l], ".2f"), "%", sep="")

import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(15,10), dpi=100, facecolor='gray')
plt.plot(years, prices, 'r')
plt.xlabel('Years') 
plt.ylabel('Prices')
plt.show()
# Out:
# Year 	 Percentage Increase
# ----------------------------------
# 1913	0.00%
# 1914	0.00%
# 1915	0.00%
# 1916	0.00%
# 1917	0.00%
# 1918	0.00%
# 1919	0.00%
# 1920	0.00%
# 1921	0.00%
# 1922	0.00%
# 1923	0.00%
# 1924	0.00%
# 1925	0.00%
# 1926	0.00%
# 1927	0.00%
# 1928	0.00%
# 1929	0.00%
# 1930	0.00%
# 1931	0.00%
# 1932	0.00%
# 1933	0.00%
# 1934	0.00%
# 1935	0.00%
# 1936	0.00%
# 1937	0.00%
# 1938	0.00%
# 1939	0.00%
# 1940	0.00%
# 1941	0.00%
# 1942	0.00%
# 1943	0.00%
# 1944	0.00%
# 1945	0.00%
# 1946	0.00%
# 1947	0.00%
# 1948	0.00%
# 1949	0.00%
# 1950	0.00%
# 1951	0.00%
# 1952	0.00%
# 1953	0.00%
# 1954	0.00%
# 1955	0.00%
# 1956	28.57%
# 1957	0.00%
# 1958	30.00%
# 1959	0.00%
# 1960	0.00%
# 1961	0.00%
# 1962	23.08%
# 1963	13.33%
# 1964	0.00%
# 1965	0.00%
# 1966	0.00%
# 1967	0.00%
# 1968	0.00%
# 1969	0.00%
# 1970	0.00%
# 1971	0.00%
# 1972	0.00%
# 1973	0.00%
# 1974	25.00%
# 1975	0.00%
# 1976	0.00%
# 1977	0.00%
# 1978	33.33%
# 1979	14.29%
# 1980	0.00%
# 1981	0.00%
# 1982	0.00%
# 1983	30.00%
# 1984	0.00%
# 1985	0.00%
# 1986	0.00%
# 1987	0.00%
# 1988	16.67%
# 1989	20.00%
# 1990	0.00%
# 1991	0.00%
# 1992	16.67%
# 1993	10.00%
# 1994	0.00%
# 1995	0.00%
# 1996	0.00%
# 1997	13.04%
# 1998	0.00%
# 1999	8.00%
# 2000	0.00%
# 2001	0.00%
# 2002	0.00%
# 2003	0.00%
# 2004	16.67%
# 2005	0.00%
# 2006	0.00%
# 2007	0.00%
# 2008	0.00%
# 2009	0.00%
# 2010	0.00%
# 2011	0.00%
# 2012	25.00%
# 2013	0.00%
# 2014	0.00%
# 2015	0.00%
# 2016	0.00%
# 2017	11.11%
# 2018	0.00%
